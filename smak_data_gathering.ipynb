# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import sqlite3
import csv
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#from bs4 import BeautifulSoup
import requests
import json 
import pprint
import unidecode
from difflib import SequenceMatcher

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

conn = sqlite3.connect('billboard.db') # automatically creates new file for 
c = conn.cursor()
c.execute('PRAGMA foreign_keys = ON')
# Out:
# /kaggle/input/billboardchart/charts.csv
# /kaggle/input/billboard-the-hot-100-songs/charts.csv

# %%
c.execute('''DROP TABLE IF EXISTS billboard;''')

create_billboard = '''
CREATE TABLE billboard(
  "date" TEXT,
  "rank" INT,
  "song" TEXT,
  "artist" TEXT,
  "last_week" INT,
  "peak_rank" INT,
  "weeks_on_board" INT
);
'''

# Use the execute function to execute the command
c.execute(create_billboard)

# And then commit the changes to the file
conn.commit()

a_file = open("../input/billboardchart/charts.csv")
rows = csv.reader(a_file)
c.executemany("INSERT INTO billboard VALUES (?, ?, ?, ?, ?, ?, ?)", rows)
conn.commit()

# %%
c.execute('''
    UPDATE billboard
    SET date = substr(date, 0, 5);''')

conn.commit()

# %%
c.execute('''DROP TABLE IF EXISTS billboards_filtered;''')

c.execute('''
    CREATE TABLE billboards_filtered AS
        WITH summary AS (
            SELECT b.date, 
                   b.song, 
                   b.artist,
                   b.peak_rank,
                   b.weeks_on_board,
                   ROW_NUMBER() OVER(PARTITION BY b.song, b.artist 
                                         ORDER BY b.weeks_on_board DESC) AS rank
              FROM billboard b)
         SELECT *
           FROM summary
         WHERE rank = 1;''')

conn.commit()

# %%
c.execute('''DROP TABLE IF EXISTS popular_songs;''')

c.execute('''
CREATE TABLE popular_songs(
  "date" TEXT,
  "song" TEXT,
  "artist" TEXT,
  "peak_rank" TEXT,
  "weeks_on_board" TEXT
);''')

for yr in range(1958, 2021):
    c.execute('''
    INSERT INTO popular_songs (date, song, artist, peak_rank, weeks_on_board) 
    SELECT date as year, song, artist, peak_rank, weeks_on_board
    FROM billboards_filtered
    where date = ''' + str(yr) + ''' 
    order by peak_rank asc, weeks_on_board desc
    limit 20;''')
    
conn.commit()

# %%
c.execute('''DROP TABLE billboard;''')
c.execute('''DROP TABLE billboards_filtered;''')

# %%
c.execute('''
SELECT song, artist
FROM popular_songs;''')

songs_list = c.fetchall()

# %%
### SPOTIFY API

CLIENT_ID = '80a481dc1cee412f91416881e7a11029'
CLIENT_SECRET = '51addb341d9a41ba8778f460114a880e'

AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# %%
def replace_special_char(name):
    name = name.lower()
    name = name.replace("&", "")
    name = name.replace("-", "")
    name = name.replace("/", "")
    return name

def clean_song(song):
    split_on_spaces = song.split(' ')
    name = ''
    for word in split_on_spaces:
        if 'feat.' in word.lower() or 'featuring' in word.lower():
            break
        name += word + " "
    
    name = name.strip()
    unaccented_string = unidecode.unidecode(name) 
    
    return replace_special_char(unaccented_string)


def clean_artist(given_artist):
    if "featuring" in given_artist:
        given_artist = given_artist.replace("featuring","")
    elif "feat." in given_artist:
        given_artist = given_artist.replace("feat.","")
    return replace_special_char(unidecode.unidecode(given_artist.lower()))

# %%
# actual GET request with proper header

# assuming that the most popular song is first when there are two artists

list_ids = []

for (song, given_artist) in songs_list[800:1200]:
    song_id = None
    cleaned_song = ''
    correct_track_name = False

    song = clean_song(song.lower())
    given_artist = clean_artist(given_artist.lower())
    
    
    song_spaced = requests.utils.quote(song + " " + given_artist)
    r = requests.get(BASE_URL + 'search/?q=' + song_spaced + '&type=track', headers=headers)
    r = r.json()
    
    
    
    for track in r['tracks']['items']:
        artist_contained = True
        for artist in track['artists']:
#             print('potential artist:', artist['name'])
            
            spotify_artist = clean_artist(artist['name'])
            given_artist = clean_artist(given_artist)
            
            if (spotify_artist not in given_artist) and (given_artist not in spotify_artist):
                artist_contained = False
                break
    
#             print('found artist:', artist['name'])

        cleaned_song = clean_song(track['name'])
        
        print('given: ', song, given_artist, 'found: ', cleaned_song, artist_contained)

        if artist_contained and (cleaned_song in clean_song(song) or clean_song(song) in cleaned_song):
            correct_track_name = (cleaned_song == song)
            song_id = track['id']
            list_ids.append(song_id)
            break
    
    # assuming first one is most popular
    max_sim_ratio = 0
    if len(r['tracks']['items']) > 0 and song_id == None:
        max_id = None
    
        for curr_track in r['tracks']['items']:
            artists = ''
            for artist in curr_track['artists']:
                artists += " " + clean_artist(artist['name'])

            sim_ratio = SequenceMatcher(None, clean_song(song) + clean_artist(given_artist), clean_song(curr_track['name']) + artists).ratio()
            if sim_ratio >= 0.6 and sim_ratio > max_sim_ratio:
                max_sim_ratio = sim_ratio
                max_id = curr_track['id']
                    
        song_id = max_id
            
    print('********* id', song_id, ('*********'))       
    
#print(list_ids)
# Out:
# given:  truly madly deeply savage garden found:  truly madly deeply True
# ********* id 013AWvizllIUEC2FOBzOnh *********
# given:  together again janet found:  together again True
# ********* id 1GrikfH0jDejDvrxo84n4P *********
# given:  candle in the wind 1997something about the way you look tonight elton john found:  something about the way you look tonight  edit version True
# ********* id 5LjSxAIKwyZvQqJ04ZQ0Da *********
# given:  all my life kci  jojo found:  all my life True
# ********* id 5GorFaKkP2mLREQvhSblIg *********
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# given:  i'll be missing you puff daddy  faith evans  112 found:  i'll be missing you False
# ********* id 3QHONiXGMGU3z68mQInncF *********
# given:  gettin' jiggy wit it will smith found:  gettin' jiggy wit it True
# ********* id 0weAUscowxeqDtpCgtbpgp *********
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems (stripped version) False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems (stripped version) False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems (stripped version) False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems (stripped version) False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems (stripped version) False
# given:  mo money mo problems the notorious b.i.g.  puff daddy  mase found:  mo money mo problems  (tribute to the notorious b.i.g. False
# ********* id 4h1T8pUzl9VtudWWlVAxxz *********
# given:  the boy is mine brandy  monica found:  the boy is mine True
# ********* id 6sHsXIJoEN5JpdkGMQDJxt *********
# given:  nice  slow usher found:  nice  slow True
# ********* id 5L0KDoZklMgs9GPoonneEl *********
# given:  4 seasons of loneliness boyz ii men found:  4 seasons of loneliness True
# ********* id 027tq4cWr0kRxLTfdxvM1L *********
# given:  honey mariah carey found:  honey True
# ********* id 5NaOWLOmVjcA3M5spRATN9 *********
# given:  my all mariah carey found:  my all True
# ********* id 5rWzxloNXvbRPhlC1O2b6T *********
# given:  have you ever? brandy found:  have you ever True
# ********* id 6tBD4yjOf9P8rWwUlXdJFm *********
# given:  doo wop (that thing) lauryn hill found:  doo wop (that thing) True
# ********* id 0uEp9E98JB5awlA084uaIg *********
# given:  bailamos enrique iglesias found:  bailamos True
# ********* id 2bbeNsFmjZqdoDhjLsKNWe *********
# given:  bills, bills, bills destiny's child found:  bills, bills, bills True
# ********* id 1Oi2zpmL81Q0yScF1zxaC0 *********
# given:  i don't want to miss a thing aerosmith found:  i don't want to miss a thing  from "armageddon" soundtrack True
# ********* id 225xvV8r1yKMHErSWivnow *********
# given:  livin' la vida loca ricky martin found:  livin' la vida loca True
# ********* id 0Ph6L4l8dYUuXFmb71Ajnd *********
# given:  one week barenaked ladies found:  one week True
# ********* id 29hBRadFZf9QTGRHZmxm65 *********
# given:  i'm your angel r. kelly  celine dion found:  i'm your angel (with celine dion) True
# ********* id 0QWFiyhOqFu9RP8qzP6z5L *********
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west  album version  no intro False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west (made famous by will smith False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west (as made famous by will smith False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west (as made famous by will smith False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west (in the style of will smith, dru hill  kool mo dee) [karaoke version] False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west (in the style of will smith False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west (in the style of will smith w dru hill  kool mo dee) [karaoke version] False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west (in the style of will smith wdru hill  kool mo dee)  instrumental only False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west (in the style of will smith False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west (in the style of will smith False
# given:  wild wild west will smith  dru hill  kool mo dee found:  wild wild west (in the style of will smith wdru hill  kool mo dee)  demo vocal version False
# ********* id 5AMvBCtX2rspUdoeJ9IsPN *********
# given:  kiss me sixpence none the richer found:  kiss me True
# ********* id 754kgU5rWscRTfvlsuEwFp *********
# given:  nobody's supposed to be here deborah cox found:  nobody's supposed to be here True
# ********* id 51QxenFmXlJXUN9mpvxlaL *********
# given:  smooth santana  rob thomas found:  smooth True
# ********* id 0n2SEXB2qoRQg171q7XqeW *********
# given:  amazed lonestar found:  amazed True
# ********* id 6qc34bnVOyqGDPni8H5W0U *********
# given:  everything you want vertical horizon found:  everything you want True
# ********* id 4cKGldbhGJniI8BrB3K6tb *********
# given:  i knew i loved you savage garden found:  i knew i loved you True
# ********* id 6nozDLxeL0TE4MS9GqYU1v *********
# given:  say my name destiny's child found:  say my name True
# ********* id 7H6ev70Weq6DdpZyyTmUXk *********
# given:  try again aaliyah found:  try again  aaliyah remix False
# given:  try again aaliyah found:  feel something different False
# given:  try again aaliyah found:  try again True
# ********* id 52IKUZIr66lMvy7COxmG9x *********
# given:  unpretty tlc found:  unpretty True
# ********* id 0BUoLE4o9eVahDHvTqak67 *********
# given:  incomplete sisqo found:  incomplete True
# ********* id 3w8Mw9GHYepoTWOSdiyosj *********
# ********* id None *********
# given:  it's gonna be me 'n sync found:  it's gonna be me False
# given:  it's gonna be me 'n sync found:  it's gonna be me False
# given:  it's gonna be me 'n sync found:  it's gonna be me False
# given:  it's gonna be me 'n sync found:  it's gonna be me (lullaby version of n sync) False
# given:  it's gonna be me 'n sync found:  it's gonna be me False
# given:  it's gonna be me 'n sync found:  it's gonna be me (in the style of 'nsync') False
# given:  it's gonna be me 'n sync found:  it's gonna be me (in the style of 'n' sync) [karaoke version] False
# given:  it's gonna be me 'n sync found:  it's gonna be me (originally performed by n sync) [instrumental] False
# given:  it's gonna be me 'n sync found:  it's gonna be me (karaoke instrumental track)[in the style of 'n sync] False
# given:  it's gonna be me 'n sync found:  it's gonna be me  (demonstration version) [in the style of 'n sync] False
# given:  it's gonna be me 'n sync found:  it's gonna be me  (karaoke version) [in the style of 'n sync] False
# given:  it's gonna be me 'n sync found:  it's gonna be me (karaoke instrumental track) [in the style of 'n sync] False
# given:  it's gonna be me 'n sync found:  it's gonna be me (karaoke instrumental track) [in the style of 'n sync] False
# given:  it's gonna be me 'n sync found:  it's gonna be me (karaoke instrumental track) [in the style of 'n sync] False
# given:  it's gonna be me 'n sync found:  it's gonna be me (karaoke instrumental track) [in the style of 'n sync] False
# given:  it's gonna be me 'n sync found:  it's gonna be me (originally performed by n' sync) [vocal version] False
# given:  it's gonna be me 'n sync found:  it's gonna be me (originally performed by n sync) [karaoke version] False
# given:  it's gonna be me 'n sync found:  it's gonna be me (originally performed by n' sync) [karaoke version] False
# given:  it's gonna be me 'n sync found:  it's gonna be me (originally performed by n sync) [karaoke version] False
# given:  it's gonna be me 'n sync found:  it's gonna be me : originally performed by n sync karaoke verison False
# ********* id 2AW37v0bDyuOzGP3XnmFuA *********
# given:  doesn't really matter janet found:  doesn't really matter True
# ********* id 0ekdT3jOhn3LinWtqHhmsw *********
# given:  what a girl wants christina aguilera found:  what a girl wants True
# ********* id 5bGmuxShUba9maPswDnhCs *********
# given:  come on over baby (all i want is you) christina aguilera found:  come on over baby (all i want is you)  radio version True
# ********* id 7A0apkTSTvMbSI7yplcmlh *********
# given:  be with you enrique iglesias found:  be with you True
# ********* id 1lZ4j5WBURBwZ0M5TT46wP *********
# given:  heartbreaker mariah carey  jayz found:  heartbreaker True
# ********* id 0jsANwwkkHyyeNyuTFq2XO *********
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you (karaoke version)  originally performed by 98 degrees, joe  mariah carey False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you (originally performed by mariah carey, joe  98 degrees) [karaoke version] False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you (in the style of mariah carey, joe  98 degrees) [karaoke version] False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you (in the style of mariah carey joe  98 degrees) [karaoke version] False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you (in the style of mariah carey, joe  98 degrees) [karaoke version] False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you (in the style of mariah carey, joe  98 degrees) [karaoke version] False
# given:  thank god i found you mariah carey  joe  98 degrees found:  thank god i found you  karaoke version in the style of mariah carey False
# ********* id 1RS3LStQYhju50eBdD9Uul *********
# given:  breathe faith hill found:  breathe True
# ********* id 3y4LxiYMgDl4RethdzpmNe *********
# given:  back at one brian mcknight found:  back at one True
# ********* id 6mwA6YiKDjAUG8kWvRRUPh *********
# given:  he wasn't man enough toni braxton found:  he wasn't man enough True
# ********* id 7f1Dmr246cJ9uQYdbplTbh *********
# given:  you sang to me marc anthony found:  you sang to me True
# ********* id 2dwhMQsFeHr2S787WxqAqW *********
# given:  with arms wide open creed found:  with arms wide open True
# ********* id 0eKyHwckh9vQb8ncZ2DXCs *********
# given:  bent matchbox twenty found:  bent True
# ********* id 6fA7akEuTUL3dW1V0GELaZ *********
# given:  angel shaggy  rayvon found:  angel True
# ********* id 7FDV5ELOJHCGLe52AnttEd *********
# given:  independent women part i destiny's child found:  independent women part 1 False
# given:  independent women part i destiny's child found:  independent women part 1 (karaoke in the style of destiny's child) False
# given:  independent women part i destiny's child found:  independent women part 1 (as made famous by destiny's child) False
# given:  independent women part i destiny's child found:  independent women part 1 (as made famous by destiny's child) False
# given:  independent women part i destiny's child found:  independent women part 1 (as made famous by destiny's child) False
# given:  independent women part i destiny's child found:  independent women part 1 False
# given:  independent women part i destiny's child found:  independent women part 2 (in the style of destiny's child) [karaoke version] False
# given:  independent women part i destiny's child found:  independent women part 1 (in the style of destiny's child) [karaoke version] False
# given:  independent women part i destiny's child found:  independent women part 2 (in the style of destiny's child) [karaoke version] False
# given:  independent women part i destiny's child found:  independent women part 1 False
# given:  independent women part i destiny's child found:  independent women part 1 (in the style of destiny's child) [karaoke version] False
# given:  independent women part i destiny's child found:  independent women part
# ********* id 4WY3HyGXsWqjFRCVD6gnTe *********
# given:  slow motion juvenile  soulja slim found:  slow motion True
# ********* id 6ihObRBTB8xdSH2mlERtOX *********
# given:  stand up ludacris  shawnna found:  stand up True
# ********* id 5V8sLQVHcoMzDx0kMQK5Kh *********
# given:  confessions part ii usher found:  confessions part ii True
# ********* id 7wBThXx7BGZHJJ3aN3OPvv *********
# given:  slow jamz twista  kanye west  jamie foxx found:  slow jamz True
# ********* id 3A4cpTBPaIQdtPFb5JxtaX *********
# given:  i believe fantasia found:  i believe True
# ********* id 2zZJnAlhgvW6DERn1tu3fb *********
# given:  get low lil jon  the east side boyz  ying yang twins found:  get low True
# ********* id 0r2Bul2NuCViraT2zX1l5j *********
# given:  the reason hoobastank found:  the reason True
# ********* id 77loZpT5Y5PRP1S451P9Yz *********
# given:  i don't wanna know mario winans  enya  p. diddy found:  i don't wanna know True
# ********* id 2yr2HnFYl7XvqJk4fXoQBt *********
# given:  tipsy jkwon found:  tipsy  club mix True
# ********* id 0jSMveIWvnhDIvzqN74Uc7 *********
# given:  sunshine lil' flip  lea found:  sunshine True
# ********* id 4s0o8TJHfX9LLHa0umnOzT *********
# given:  one call away chingy  j. weav found:  one call away False
# given:  one call away chingy  j. weav found:  one call away False
# given:  one call away chingy  j. weav found:  one call away False
# given:  one call away chingy  j. weav found:  one call away False
# given:  one call away chingy  j. weav found:  one call away  chopped and screwed False
# given:  one call away chingy  j. weav found:  one call away  live False
# given:  one call away chingy  j. weav found:  one call away False
# given:  one call away chingy  j. weav found:  one call away (in the style of chingy  j weav) [karaoke version] False
# given:  one call away chingy  j. weav found:  one call away (in the style of chingy and j. weav) [karaoke version] False
# given:  one call away chingy  j. weav found:  one call away (in the style of chingy and j. weav) [karaoke version] False
# given:  one call away chingy  j. weav found:  one call away (originally performed by chingy False
# given:  one call away chingy  j. weav found:  one call away  in the style of chingy False
# given:  one call away chingy  j. weav found:  one call away [in the style of "chingy  j weav"] {karaoke version} False
# given:  one call away chingy  j. weav found:  one call away [in the style of "chingy  j weav"] {karaoke version} False
# given:  one call away chingy  j. weav found:  one call away4  in the style of chingy False
# given:  one call away chingy  j. weav found:  one call away [in the style of "chingy  j weav"] {karaoke demonstration with lead vocal} False
# given:  one call away chingy  j. weav found:  one call away [in the style of "chingy  j weav"] {karaoke demonstration with lead vocal} False
# given:  one call away chingy  j. weav found:  one call away (in the style of "chingy False
# ********* id 0UNTBB02C1aB55Fu4H63qd *********
# given:  milkshake kelis found:  milkshake  radio mix True
# ********* id 2s0ouHqJebHfiQ6C1GUFJd *********
# given:  naughty girl beyonce found:  naughty girl True
# ********* id 0YGQ3hZcRLC5YX7o0hdmHg *********
# given:  holidae in chingy  ludacris  snoop dogg found:  holidae in True
# ********* id 0FmCLEHfINGqwlyzvklNqy *********
# given:  goodies ciara  petey pablo found:  goodies True
# ********* id 3dFwpxh2yH7C7p9BGEKLVB *********
# given:  let me love you mario found:  let me love you True
# ********* id 3ibKnFDaa3GhpPGlOUj7ff *********
# given:  hollaback girl gwen stefani found:  hollaback girl True
# ********* id 0LzrhCZFXW94Y8nwtTuRlw *********
# given:  lean back terror squad found:  lean back False
# given:  lean back terror squad found:
# given:  pon de replay rihanna found:  pon de replay True
# ********* id 4TsmezEQVSZNNPv5RJ65Ov *********
# given:  hate it or love it the game  50 cent found:  hate it or love it True
# ********* id 2wGSgTmgSF3xjRrHkTc25R *********
# given:  oh ciara  ludacris found:  oh True
# ********* id 7i7UIbm5E0DD7aSOYvwp2v *********
# given:  inside your heaven bo bice found:  inside your heaven True
# ********* id 6SZBK8Z2Tdv7vgO3ZJnHTN *********
# given:  disco inferno 50 cent found:  disco inferno True
# ********* id 69bHJ9qs5FrUJbKP8xU8uZ *********
# given:  lose control missy elliott  ciara  fat man scoop found:  lose control False
# given:  lose control missy elliott  ciara  fat man scoop found:  lose control False
# given:  lose control missy elliott  ciara  fat man scoop found:  lose control  originally performed by missy elliott ft. ciara  fat man scoop False
# given:  lose control missy elliott  ciara  fat man scoop found:  lose control (karaoke version)  in the style of missy elliott, ciara, fat man scoop False
# given:  lose control missy elliott  ciara  fat man scoop found:  lose control (karaoke version) [in the style of missy elliott, ciara  fat man scoop] False
# given:  lose control missy elliott  ciara  fat man scoop found:  lose control  official bar karaoke version in the style of missy elliott ft. ciara  fat man scoop False
# ********* id 0UaMYEvWZi0ZqiDOoHU3YI *********
# given:  just a lil bit 50 cent found:  just a lil bit True
# ********* id 4nva9EpKntUTs6CRSGBCn9 *********
# given:  don't phunk with my heart the black eyed peas found:  don't phunk with my heart True
# ********* id 4MtDnnAJ1AtWit10FRmZdW *********
# given:  over and over nelly  tim mcgraw found:  over and over True
# ********* id 2b8QQqf8Vwb7bfz22ja8Fk *********
# given:  we belong together mariah carey found:  we belong together True
# ********* id 3LmvfNUQtglbTrydsdIqFU *********
# given:  gold digger kanye west  jamie foxx found:  gold digger True
# ********* id 1PS1QMdUqOal0ai3Gt7sDQ *********
# given:  run it! chris brown found:  run it! False
# given:  run it! chris brown found:  run it!  no rap version True
# ********* id 248cTipV63OJIG1XBH94wI *********
# given:  you're beautiful james blunt found:  you're beautiful True
# ********* id 0vg4WnUWvze6pBOJDTq99k *********
# given:  bad day daniel powter found:  bad day True
# ...
# given:  blurred lines robin thicke  t.i. + pharrell found:  blurred lines (originally performed by robin thicke, t.i. and pharrell) [karaoke version] False
# given:  blurred lines robin thicke  t.i. + pharrell found:  blurred lines (karaoke version) [originally performed by robin thicke, t.i. and pharrell] False
# given:  blurred lines robin thicke  t.i. + pharrell found:  blurred lines (karaoke version)  originally performed by robin thicke  t.i. pharrell False
# given:  blurred lines robin thicke  t.i. + pharrell found:  blurred lines (originally performed by robin thicke, t.i and pharrell) [karaoke version] False
# given:  blurred lines robin thicke  t.i. + pharrell found:  blurred lines (karaoke version)  originally performed by robin thicke and t.i. pharrell False
# given:  blurred lines robin thicke  t.i. + pharrell found:  blurred lines (originally performed by robin thicke, t.i.  pharrell) [karaoke version] False
# given:  blurred lines robin thicke  t.i. + pharrell found:  blurred lines (karaoke version)  originally performed by robin thicke, t.i. and pharrell False
# given:  blurred lines robin thicke  t.i. + pharrell found:  blurred lines (originally performed by robin thicke, t.i.  pharrell) [karaoke version] False
# ********* id 2pgbGOb00WrlXY3ZRFKn7v *********
# given:  happy pharrell williams found:  happy  from "despicable me 2" True
# ********* id 60nZcImufyMA1MKQY3dcCH *********
# given:  royals lorde found:  royals True
# ********* id 2dLLR6qlu5UJ5gk0dKz0h3 *********
# given:  fancy iggy azalea  charli xcx found:  fancy True
# ********* id 3oiMJQAWVaxSubJ7b2VUtX *********
# given:  timber pitbull  ke$ha found:  timber False
# given:  timber pitbull  ke$ha found:  timber False
# given:  timber pitbull  ke$ha found:  timber False
# given:  timber pitbull  ke$ha found:  timber False
# given:  timber pitbull  ke$ha found:  timber False
# given:  timber pitbull  ke$ha found:  timber False
# given:  timber pitbull  ke$ha found:  timber False
# given:  timber pitbull  ke$ha found:  timber False
# given:  timber pitbull  ke$ha found:  timber False
# given:  timber pitbull  ke$ha found:  timber (originally by pitbull  ke$ha)  karaoke version False
# given:  timber pitbull  ke$ha found:  timber False
# given:  timber pitbull  ke$ha found:  timber  tribute to pitbull and ke$ha False
# given:  timber pitbull  ke$ha found:  timber  tribute to pitbull and ke$ha False
# given:  timber pitbull  ke$ha found:  timber  tribute to pitbull and ke$ha False
# given:  timber pitbull  ke$ha found:  timber  ringtone tribute to pitbull and ke$ha False
# given:  timber pitbull  ke$ha found:  timber (originally by pitbull False
# given:  timber pitbull  ke$ha found:  timber  tribute to pitbull and ke$
# ********* id 1p80LdxRV74UKvL8gnD7ky *********
# given:  bad blood taylor swift  kendrick lamar found:  bad blood True
# ********* id 6xsEAm6w9oMQYYg3jkEkMT *********
# given:  thinking out loud ed sheeran found:  thinking out loud True
# ********* id 34gCuhDGsG4bRPIf9bb02f *********
# given:  stay with me sam smith found:  stay with me True
# ********* id 5Nm9ERjJZ5oyfXZTECKmRt *********
# given:  sugar maroon 5 found:  sugar True
# ********* id 2iuZJX9X9P0GKaE93xcPjk *********
# given:  take me to church hozier found:  take me to church True
# ********* id 1CS7Sd1u5tWkstBhpssyjP *********
# given:  work it missy "misdemeanor" elliott found:  work it  in the style of missy "misdemeanor" elliott (karaoke version teaching vocal) False
# given:  work it missy "misdemeanor" elliott found:  work it  in the style of missy "misdemeanor" elliott (karaoke version teaching vocal) False
# given:  work it missy "misdemeanor" elliott found:  work it7  in the style of missy "misdemeanor" elliott (karaoke version instrumental only) False
# given:  work it missy "misdemeanor" elliott found:  work it7  in the style of missy "misdemeanor" elliott (karaoke version instrumental only) False
# ********* id None *********
# given:  anaconda nicki minaj found:  anaconda True
# ********* id 794F99D5BQHS5ZGRXAs7I5 *********
# given:  earned it (fifty shades of grey) the weeknd found:  earned it (fifty shades of grey) True
# ********* id 4frLb7nWtsz2ymBE6k2GRP *********
# given:  habits (stay high) tove lo found:  habits (stay high) True
# ********* id 14OxJlLdcHNpgsm4DRwDOB *********
# given:  love me like you do ellie goulding found:  love me like you do  from "fifty shades of grey" True
# ********* id 3zHq9ouUJQFQRf3cm1rRLu *********
# given:  animals maroon 5 found:  animals True
# ********* id 5PFCVlGqsRsBnkKI4bHsAJ *********
# given:  bang bang jessie j, ariana grande  nicki minaj found:  bang bang True
# ********* id 0puf9yIluy9W0vpMEUoAnN *********
# given:  black widow iggy azalea  rita ora found:  black widow True
# ********* id 7pNC5ZIKtwUK0ReSpM3P9f *********
# given:  shut up and dance walk the moon found:  shut up and dance True
# ********* id 4kbj5MwxO1bq9wjT5g9HaA *********
# given:  lips are movin meghan trainor found:  lips are movin True
# ********* id 6gj08XDlv9Duc2fPOxUmVD *********
# given:  fourfiveseconds rihanna  kanye west  paul mccartney found:  fourfiveseconds True
# ********* id 78TTtXnFQPzwqlbtbwqN0y *********
# given:  uptown funk! mark ronson  bruno mars found:  uptown funk True
# ********* id 32OlwWuMpZ6b0aN2RZOeMS *********
# given:  see you again wiz khalifa  charlie puth found:  see you again True
# ********* id 2JzZzZUQj3Qff7wapcbKjc *********
# given:  the hills the weeknd found:  the hills True
# ********* id 7fBv7CLKzipRk6EC6TWHOB *********
# given:  sorry justin bieber found:  sorry True
# ********* id 3ufzPoNZLUJMXRPTbKmpNv *********
# given:  can't feel my face the weeknd found:  can't feel my face True
# ********* id 22VdIZQfgXJea34mQxlt81 *********
# given:  love yourself justin bieber found:  love yourself True
# ********* id 6ahRqRXINOZC9f2mX50gZH *********
# given:  panda desiigner found:  panda True
# ********* id 275a9yzwGB6ncAW4SxY7q3 *********
# given:  one dance drake  wizkid  kyla found:  one dance True
# ********* id 1zi7xx7UVEFkmKfv06H8x0 *********
# given:  work rihanna  drake found:  work True
# ********* id 72TFWvU3wUYdUuxejTTIzt *********
# given:  cheerleader omi found:  cheerleader  felix jaehn remix radio edit True
# ********* id 023OVLNzXhX0j7CxswUt6D *********
# given:  what do you mean? justin bieber found:  what do you mean?  acoustic True
# ********* id 727fJm3FMeB0ppAp6JChfg *********
# given:  hello adele found:  hello True
# ********* id 62PaSfnXSMyLshYJrlTuL3 *********
# given:  pillowtalk zayn found:  pillowtalk True
# ********* id 0PDUDa38GO8lMxLCRc4lL1 *********
# given:  when doves cry prince found:  when doves cry True
# ********* id 51H2y6YrNNXcy3dfc3qSbA *********
# given:  let's go crazy prince and the revolution found:  let's go crazy True
# ********* id 0QeI79sp1vS8L3JgpEO7mD *********
# given:  kiss prince and the revolution found:  kiss True
# ********* id 62LJFaYihsdVrrkgUOJC05 *********
# given:  stressed out twenty one pilots found:  stressed out True
# ********* id 3CRDbSIZ4r5MsZ0YwxuEkn *********
# given:  trap queen fetty wap found:  trap queen True
# ********* id 2d8JP84HNLKhmd6IYOoupQ *********
# given:  7 years lukas graham found:  7 years True
# ********* id 5kqIPrATaCc2LqxVWzQGbk *********
# given:  hotline bling drake found:  hotline bling True
# ********* id 0wwPcA6wtMf6HUMpIRdeP7 *********
# given:  can't stop the feeling! justin timberlake found:  can't stop the feeling! (original song from dreamworks animation's "trolls") True
# ********* id 1WkMMavIMc4JZ8cfMmxHkI *********
# given:  cheap thrills sia  sean paul found:  cheap thrills True
# ********* id 6b3b7lILUJqXcp6w9wNQSm *********
# given:  closer the chainsmokers  halsey found:  closer True
# ********* id 7BKLCZ1jbUBVqRi2FVlTVw *********
# given:  humble. kendrick lamar found:  humble. True
# ********* id 7KXjTSCq5nL1LoYtL7XAwS *********
# given:  bad and boujee migos  lil uzi vert found:  bad and boujee True
# ********* id 4Km5HrUvYTaSUfiSGPJeQR *********
# given:  starboy the weeknd  daft punk found:  starboy True
# ********* id 7MXVkk9YMctZqd1Srtv4MB *********
# given:  black beatles rae sremmurd  gucci mane found:  black beatles True
# ********* id 6fujklziTHa8uoM5OQSfIo *********
# given:  careless whisper wham!  george michael found:  careless whisper  smooth chill out mix False
# given:  careless whisper wham!  george michael found:  careless whisper  in the style of wham (george michael) False
# given:  careless whisper wham!  george michael found:  careless whisper (made popular by wham! ft. george michael) [karaoke version] False
# given:  careless whisper wham!  george michael found:  careless whisper (made popular by wham! ft. george michael) [vocal version] False
# given:  careless whisper wham!  george michael found:  careless whisper (in the style of wham! + george michael) [karaoke version] False
# given:  careless whisper wham!  george michael found:  careless whisper (in the style of 'george michael') False
# given:  careless whisper wham!  george michael found:  careless whisper (in the style of wham! False
# given:  careless whisper wham!  george michael found:  careless whisper (originally performed by george michael) [karaoke version] False
# given:  careless whisper wham!  george michael found:  careless whisper (originally performed by george michael) [full vocal version] False
# given:  careless whisper wham!  george michael found:  careless whisper (karaoke instrumental track) [in the style of wham] False
# given:  careless whisper wham!  george michael found:  careless whisper (karaoke lead vocal demo) [in the style of wham] False
# given:  careless whisper wham!  george michael found:  careless whisper False
# given:  careless whisper wham!  george michael found:  careless whisper (karaoke version) False
# given:  careless whisper wham!  george michael found:  careless whisper (karaoke version) False
# given:  careless whisper wham!  george michael found:  careless whisper  unqualified demo False
# given:  careless whisper wham!  george michael found:  careless whisper  unqualified demo False
# given:  careless whisper wham!  george michael found:  careless whispers  sloppy scissors edit False
# given:  careless whisper wham!  george michael found:  careless whispers  sloppy scissors edit False
# given:  careless whisper wham!  george michael found:  one more time  unqualified demo False
# given:  careless whisper wham!  george michael found:  freedoms  pre and post 90 edit False
# ********* id 5EifA3iGpLr4bh1JFisyJZ *********
# given:  i'm the one dj khaled  justin bieber, quavo, chance the rapper  lil wayne found:  i'm the one True
# ********* id 1jYiIOC5d6soxkJP81fxq2 *********
# given:  faith george michael found:  faith  remastered True
# ********* id 0HEmnAUT8PHznIAAmVXqFJ *********
# given:  heathens twenty one pilots found:  heathens True
# ********* id 6i0V12jOa3mr6uu4WYhUBr *********
# given:  in the end linkin park found:  in the end True
# ********* id 60a0Rd6pjrkxjPbaKzXjfq *********
# given:  bad romance lady gaga found:  bad romance True
# ********* id 0SiywuOBRcynK0uKGWdCnn *********
# given:  cold water major lazer  justin bieber  mo found:  cold water True
# ********* id 7zsXy7vlHdItvUSH8EwQss *********
# given:  i don't wanna live forever (fifty shades darker) zayn  taylor swift found:  i don't wanna live forever (fifty shades darker) True
# ********* id 55n9yjI6qqXh5F2mYvUc2y *********
# given:  wild thoughts dj khaled  rihanna  bryson tiller found:  wild thoughts True
# ********* id 45XhKYRRkyeqoW3teSOkCM *********
# given:  don't let me down the chainsmokers  daya found:  don't let me down True
# ********* id 1i1fxkWeaMmKEB4T7zqbzK *********
# given:  something just like this the chainsmokers  coldplay found:  something just like this True
# ********* id 6RUKPb4LETWmmr3iAEQktW *********
# given:  24k magic bruno mars found:  24k magic True
# ********* id 0wmenBxOt6Lj8A34GNftYU *********
# given:  let me love you dj snake  justin bieber found:  let me love you True
# ********* id 0lYBSQXN6rCTvUZvg9S0lU *********

# %%
print(len(list_ids))
# Out:
# 362

# %%
# testing above

# song_spaced = requests.utils.quote('Levitating')
# r = requests.get(BASE_URL + 'search/?q=' + song_spaced + '&type=track', headers=headers)
# # my_json_data = r.json()
# # # data = json.loads(json.dumps(my_json_data['tracks']['items']))
# # for item in my_json_data['tracks']['items']:
# #     pprint.pprint(item)
# r = r.json()

# for track in r['tracks']['items']:
#     for artist in track['artists']:
#         if artist['name'] not in 'Dua Lipa Featuring DaBaby':
#             artist_contained = False
#             break
            
#     cleaned_song = clean_song(track['name'])
    
#     if artist_contained and cleaned_song == 'Levitating':
#         correct_track_name = (cleaned_song == 'Levitating')
#         song_id = track['id']
#         pprint.pprint(song_id)
#         break

# print('correct track', correct_track_name)
# print('artist contained', artist_contained)

#pprint.pprint(r)
