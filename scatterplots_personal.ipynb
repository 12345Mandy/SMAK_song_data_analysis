# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pprint as pp
import seaborn as sns
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# I copied the train data to my main drive and named it "train.csv"
path = "/content/gdrive/My Drive/Copy_of_train.csv"
with open(path, 'rb') as f:
  df = pd.read_csv(f)
print("Finished reading data!")
# Out:
# Finished reading data!

# %%
#df.head()

# %%
#df = pd.read_csv("/pop_songs_data.csv")

# %%
year_avg_data = []

for year in range(1958, 2021):
    this_year = df.loc[df['date'] == year]
    # date, avg_peak_rank, avg_weaks_on_board, avg_accousticness, avg_danceability, avg_duration_ms, 
    # avg_energy, avg_instrumentalness, avg_liveness, avg_loudness, avg_speechiness, avg_tempo, avg_valence
    this_info = []
    for col in ['date', 'peak_rank', 'weeks_on_board', 'acousticness', 'danceability', 'duration_ms', 'energy', 
                'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']:
        this_info.append(this_year[col].mean())
    year_avg_data.append(this_info)

# %%
#pp.pprint(year_avg_data)

# %%
cols = ['avg_date', 'avg_peak_rank', 'avg_weeks_on_board', 'avg_accousticness', 
        'avg_danceability', 'avg_duration_ms', 'avg_energy', 'avg_instrumentalness', 
        'avg_liveness', 'avg_loudness', 'avg_speechiness', 'avg_tempo', 'avg_valence']

# %%
year_avgs_df = pd.DataFrame(year_avg_data, columns=cols)

# %%
#print(year_avg_data[0:3])

# %%
def make_all_data_scatter_plot(metric):
  scatter_plot = sns.scatterplot()

# %%
def make_scatter_plots(for_y):
  scatter_plot = sns.catplot(data=year_avgs_df,
            kind="strip",
            x='avg_date',
            y= for_y,
            height=5,
            aspect=6
            ).set(
                title= for_y + ' per year'
            )
  return scatter_plot

# %%
def make_all_scatterplots():
  for col in cols[1:]:
    plot = make_scatter_plots(col)
    plot.savefig(col + '_output_scatter.png')
    files.download(col + '_output_scatter.png')
  print('Done making scatterplots')

# %%
make_all_scatterplots()
# Out:
# Done making scatterplots

# %%
cols2 = ['date', 'peak_rank', 'weeks_on_board', 'acousticness', 
        'danceability', 'duration_ms', 'energy', 'instrumentalness', 
        'liveness', 'loudness', 'speechiness', 'tempo', 'valence']

# %%
# year_data = []

# for row in df:
#     this_info = [year]
#     for col in ['date', 'peak_rank', 'weeks_on_board', 'acousticness', 'danceability', 'duration_ms', 'energy', 
#                 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']:
#                 this_info.append(row[col])
#     year_data.append(this_info)

# %%
# year_df2 = pd.DataFrame(pd, columns=cols2)

# %%
def make_all_data_scatter_plot2(metric):
  scatter_plot = sns.scatterplot()

# %%
def make_scatter_plots2(for_y):
  scatter_plot = sns.catplot(data=df,
            kind="strip",
            x='date',
            y= for_y,
            height=5,
            aspect=6
            ).set(
                title= for_y + ' per year'
            )
  return scatter_plot

# %%
def make_all_scatterplots2():
  for col in cols2[1:]:
    plot = make_scatter_plots2(col)
    plot.savefig(col + '_output_scatter.png')
    files.download(col + '_output_scatter.png')
  print('Done making scatterplots')

# %%
make_all_scatterplots2()
# Out:
# Done making scatterplots

# %%
# def make_all_data_box_plots(metric):
#   scatter_plot = sns.scatterplot()

# %%
def make_box_plots(for_y):
  # box_plot = sns.boxplot(data=df,
  #           x='date',
  #           y= for_y
  #           ).set(
  #               title= for_y + ' per year'
  #           )
  ax = sns.boxplot(data=df, x='date', y= for_y, orient="h", palette="Set2")
  return ax

# %%
def make_all_boxplots():
  for col in cols2[1:]:
    plot = make_box_plots(col)
    # plot.savefig(col + '_output_box.png')
    # files.download(col + '_output_box.png')
    fig = plot.get_figure()
    fig.savefig(col + '_output_box.png')
  print('Done making boxplots')

# %%
sns.set_theme(style="whitegrid")
make_all_boxplots()
# Out:
# Done making boxplots
